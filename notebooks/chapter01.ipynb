# %%
include("../src/Schemish.jl")
using .Schemish

# %% [markdown]
# # 1 - The Lines Sleep Tonight

# %%
line = (x) -> (w, b) -> w * x + b

line(8)(4, 6)
# Out:
# 38

# %%
line_xs = [2.0, 1.0, 4.0, 3.0]
line_ys = [1.8, 1.2, 4.2, 3.3]

using Plots
plot(line_xs, line_ys, seriestype=:scatter)

# %%
line = (x) -> (θ) -> ref(θ, 0) * x + ref(θ, 1)

line(5)(list(1,2))
# Out:
# 7
